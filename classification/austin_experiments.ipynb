# %%
from classification.cnn_preprocess import CNNPreprocess
from classification.cnn import CNN
import numpy as np
import json
from statistics import mean

def get_train_data(file_sets, preprocessed_data_path=None):
    data = {}
    if preprocessed_data_path:
        with open(preprocessed_data_path) as json_file:
            data = json.load(json_file)
    else:
        cnn_preprocess = CNNPreprocess(file_sets=file_sets)
        data = cnn_preprocess.preprocess_data()
    
    return data

# %%
# Evaluate CNN Prototype

def evaluate_cnn(file_sets, preprocessed_data_path=None):
    
    data = get_train_data(file_sets, preprocessed_data_path)
    cnn_preprocess = CNNPreprocess(file_sets=file_sets)

    X = np.array(data["values"])
    y = np.array(data["labels"])

    cnn = CNN()
    reports = cnn.validate_model_kfold(X, y)
    
    return reports

challenge_data_folder = "/Users/austinatmaja/Documents/4B/SmartScope/murmur-classifier/challenge_data"
    
file_sets = [
    ([f"{challenge_data_folder}/training-a/a" + str(i).zfill(4) for i in range(1, 410)], f"{challenge_data_folder}/training-a/"),
    ([f"{challenge_data_folder}/training-b/b" + str(i).zfill(4) for i in range(1, 491)], f"{challenge_data_folder}/training-b/"),
    ([f"{challenge_data_folder}/training-c/c" + str(i).zfill(4) for i in range(1, 32)], f"{challenge_data_folder}/training-c/"),
    ([f"{challenge_data_folder}/training-d/d" + str(i).zfill(4) for i in range(1, 56)], f"{challenge_data_folder}/training-d/"),
    ([f"{challenge_data_folder}/training-e/e" + str(i).zfill(5) for i in range(1, 2142)], f"{challenge_data_folder}/training-e/"),
    ([f"{challenge_data_folder}/training-f/f" + str(i).zfill(4) for i in range(1, 115)], f"{challenge_data_folder}/training-f/"),
]

classification_results = evaluate_cnn(file_sets)

sensitivities = [res['1']['recall'] for res in classification_results if '1' in res]
specificities = [res['0']['recall'] for res in classification_results if '0' in res]
accuracies = [res['accuracy'] for res in classification_results]

print(sensitivities, specificities, accuracies)

print("Average sensitivity ", mean(sensitivities))
print("Average specificity ", mean(specificities))
print("Average accuracy ", mean(accuracies))

# %%
challenge_data_folder = "/Users/austinatmaja/Documents/4B/SmartScope/murmur-classifier/challenge_data"
    
file_sets = [
    ([f"{challenge_data_folder}/training-a/a" + str(i).zfill(4) for i in range(1, 410)], f"{challenge_data_folder}/training-a/"),
    ([f"{challenge_data_folder}/training-b/b" + str(i).zfill(4) for i in range(1, 491)], f"{challenge_data_folder}/training-b/"),
    ([f"{challenge_data_folder}/training-c/c" + str(i).zfill(4) for i in range(1, 32)], f"{challenge_data_folder}/training-c/"),
    ([f"{challenge_data_folder}/training-d/d" + str(i).zfill(4) for i in range(1, 56)], f"{challenge_data_folder}/training-d/"),
    ([f"{challenge_data_folder}/training-e/e" + str(i).zfill(5) for i in range(1, 2142)], f"{challenge_data_folder}/training-e/"),
    ([f"{challenge_data_folder}/training-f/f" + str(i).zfill(4) for i in range(1, 115)], f"{challenge_data_folder}/training-f/"),
]

def save_cnn(file_sets, preprocessed_data_path=None):
    
    data = get_train_data(file_sets, preprocessed_data_path)
    cnn_preprocess = CNNPreprocess(file_sets=file_sets)

    X = np.array(data["values"])
    y = np.array(data["labels"])

    cnn = CNN()
    cnn.save_model(X, y)

save_cnn(file_sets)
# Out:
# Processed a file set
# Processed a file set
# Processed a file set
# Processed a file set
# Processed a file set
# Processed a file set
# Epoch 1/200
# 92/92 [==============================] - 19s 190ms/step - loss: 1.5340 - accuracy: 0.5135 - val_loss: 0.9756 - val_accuracy: 0.2531
# Epoch 2/200
# 92/92 [==============================] - 18s 193ms/step - loss: 1.2750 - accuracy: 0.3556 - val_loss: 0.6568 - val_accuracy: 0.7562
# Epoch 3/200
# 92/92 [==============================] - 19s 206ms/step - loss: 1.1200 - accuracy: 0.7191 - val_loss: 0.6913 - val_accuracy: 0.7068
# Epoch 4/200
# 92/92 [==============================] - 22s 235ms/step - loss: 0.9780 - accuracy: 0.7337 - val_loss: 0.5741 - val_accuracy: 0.7870
# Epoch 5/200
# 92/92 [==============================] - 19s 206ms/step - loss: 0.9445 - accuracy: 0.7233 - val_loss: 0.5586 - val_accuracy: 0.7870
# Epoch 6/200
# 92/92 [==============================] - 20s 215ms/step - loss: 0.8865 - accuracy: 0.7533 - val_loss: 0.5747 - val_accuracy: 0.7840
# Epoch 7/200
# 92/92 [==============================] - 18s 198ms/step - loss: 0.8362 - accuracy: 0.7608 - val_loss: 0.6042 - val_accuracy: 0.7593
# Epoch 8/200
# 92/92 [==============================] - 19s 207ms/step - loss: 0.7920 - accuracy: 0.7737 - val_loss: 0.5439 - val_accuracy: 0.7932
# Epoch 9/200
# 92/92 [==============================] - 18s 191ms/step - loss: 0.8254 - accuracy: 0.7541 - val_loss: 0.5461 - val_accuracy: 0.8488
# Epoch 10/200
# 92/92 [==============================] - 18s 195ms/step - loss: 0.8939 - accuracy: 0.7441 - val_loss: 0.5348 - val_accuracy: 0.8395
# Epoch 11/200
# 92/92 [==============================] - 17s 187ms/step - loss: 0.7994 - accuracy: 0.7897 - val_loss: 0.5457 - val_accuracy: 0.8086
# Epoch 12/200
# 92/92 [==============================] - 22s 243ms/step - loss: 0.7298 - accuracy: 0.7856 - val_loss: 0.5200 - val_accuracy: 0.8179
# Epoch 13/200
# 92/92 [==============================] - 24s 259ms/step - loss: 0.7435 - accuracy: 0.7969 - val_loss: 0.5120 - val_accuracy: 0.8210
# Epoch 14/200
# 92/92 [==============================] - 18s 196ms/step - loss: 0.7650 - accuracy: 0.7816 - val_loss: 0.5599 - val_accuracy: 0.7685
# Epoch 15/200
# 92/92 [==============================] - 24s 259ms/step - loss: 0.7335 - accuracy: 0.7869 - val_loss: 0.5084 - val_accuracy: 0.8056
# Epoch 16/200
# 92/92 [==============================] - 21s 234ms/step - loss: 0.7099 - accuracy: 0.8083 - val_loss: 0.5270 - val_accuracy: 0.8241
# Epoch 17/200
# 92/92 [==============================] - 19s 209ms/step - loss: 0.7001 - accuracy: 0.8146 - val_loss: 0.5553 - val_accuracy: 0.8395
# Epoch 18/200
# 92/92 [==============================] - 19s 206ms/step - loss: 0.7068 - accuracy: 0.8152 - val_loss: 0.6078 - val_accuracy: 0.7963
# Epoch 19/200
# 92/92 [==============================] - 27s 297ms/step - loss: 0.6685 - accuracy: 0.8247 - val_loss: 0.5223 - val_accuracy: 0.8519
# Epoch 39/200
# 92/92 [==============================] - 26s 277ms/step - loss: 0.6160 - accuracy: 0.8423 - val_loss: 0.5206 - val_accuracy: 0.8148
# Epoch 40/200
# 92/92 [==============================] - 22s 236ms/step - loss: 0.5820 - accuracy: 0.8408 - val_loss: 0.5054 - val_accuracy: 0.8333
# Epoch 41/200
# 92/92 [==============================] - 25s 271ms/step - loss: 0.5959 - accuracy: 0.8477 - val_loss: 0.5801 - val_accuracy: 0.8364
# Epoch 42/200
# 92/92 [==============================] - 23s 247ms/step - loss: 0.6122 - accuracy: 0.8504 - val_loss: 0.5585 - val_accuracy: 0.8333
# Epoch 43/200
# 92/92 [==============================] - 22s 242ms/step - loss: 0.5627 - accuracy: 0.8652 - val_loss: 0.7085 - val_accuracy: 0.8549
# Epoch 44/200
# 92/92 [==============================] - 22s 236ms/step - loss: 0.6230 - accuracy: 0.8482 - val_loss: 0.6783 - val_accuracy: 0.8426
# Epoch 45/200
# 92/92 [==============================] - 21s 229ms/step - loss: 0.5432 - accuracy: 0.8694 - val_loss: 0.5485 - val_accuracy: 0.8086
# Epoch 46/200
# 92/92 [==============================] - 23s 254ms/step - loss: 0.5847 - accuracy: 0.8511 - val_loss: 0.5846 - val_accuracy: 0.8210
# Epoch 47/200
# 92/92 [==============================] - 21s 226ms/step - loss: 0.5303 - accuracy: 0.8822 - val_loss: 0.5476 - val_accuracy: 0.8241
# Epoch 00047: early stopping
# INFO:tensorflow:Assets written to: ./cnn_model/assets

# %%
from classification.features import FeaturesProcessor
from classification.cnn_preprocess import CNNPreprocess
from classification.cnn import CNN
from classification.classifier import Classifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.model_selection import StratifiedKFold

import numpy as np

# Evaluate Combined Classifier

# c has range(1,32)
challenge_data_folder = "/Users/austinatmaja/Documents/4B/SmartScope/murmur-classifier/challenge_data"

file_sets = [
    ([f"{challenge_data_folder}/training-a/a" + str(i).zfill(4) for i in range(1, 410)], f"{challenge_data_folder}/training-a/"),
    ([f"{challenge_data_folder}/training-b/b" + str(i).zfill(4) for i in range(1, 491)], f"{challenge_data_folder}/training-b/"),
    ([f"{challenge_data_folder}/training-c/c" + str(i).zfill(4) for i in range(1, 32)], f"{challenge_data_folder}/training-c/"),
    ([f"{challenge_data_folder}/training-d/d" + str(i).zfill(4) for i in range(1, 56)], f"{challenge_data_folder}/training-d/"),
    ([f"{challenge_data_folder}/training-e/e" + str(i).zfill(5) for i in range(1, 2142)], f"{challenge_data_folder}/training-e/"),
    ([f"{challenge_data_folder}/training-f/f" + str(i).zfill(4) for i in range(1, 115)], f"{challenge_data_folder}/training-f/"),
]

# Returns a dictionary with the following structure
'''
{
    filename: {
        "cnn_features": <data>,
        "adaboost_features": <data>,
        "label": <label>
    }
}
'''
def get_combined_data(file_sets):
    # Get all abnormal records
    abnormal_records = set()
    for file_set in file_sets:
        prefix = file_set[1]
        with open("{prefix}RECORDS-abnormal".format(prefix=prefix)) as fp:
            for line in fp:
                l = line.rstrip("\n")
                abnormal_records.add(l)
    
    data = {}
    cnn_preprocess = CNNPreprocess()
    
    for file_set in file_sets:
        filenames, prefix = file_set[0], file_set[1]
        for fname in filenames:
            features_processor = FeaturesProcessor(fname)
            features = features_processor.get_all_features()
            data[fname] = {
                "adaboost_features": features
            }
            cnn_features = cnn_preprocess.process(fname)
            data[fname]["cnn_features"] = cnn_features
            if cnn_preprocess.remove_prefix(fname, prefix) in abnormal_records:
                data[fname]["label"] = 1
            else:
                data[fname]["label"] = 0
        print("Processed a file set")
    
    return data
    
combined_data = get_combined_data(file_sets)
fnames = sorted(combined_data.keys())
y = np.array([combined_data[fname]["label"] for fname in fnames])

# perform 80-20 train-test split
fnames_train, fnames_test, y_train, y_test = train_test_split(fnames, y, test_size=0.2)
X_cnn_train = np.array([combined_data[fname]["cnn_features"].tolist() for fname in fnames_train])
X_cnn_test = np.array([combined_data[fname]["cnn_features"].tolist() for fname in fnames_test])
X_adaboost_train = [combined_data[fname]["adaboost_features"] for fname in fnames_train]
X_adaboost_test = [combined_data[fname]["adaboost_features"] for fname in fnames_test]

# train CNN
cnn = CNN()
cnn_model = cnn.train_model(X_cnn_train, y_train)

# train Adaboost
adaboost = Classifier()
adaboost_model = adaboost.get_model()
adaboost_model = adaboost.train_model(adaboost_model, X_adaboost_train, y_train)

# invoke combined classifier
y_pred_adaboost = adaboost_model.predict_proba(X_adaboost_test)
y_pred_cnn = cnn_model.predict(X_cnn_test)
def get_prediction(pred_cnn, pred_adaboost):
    return 1 if pred_cnn[1] > 0.6 or pred_adaboost[1] > 0.6 else 0
y_pred = [get_prediction(y_pred_cnn[i], y_pred_adaboost[i]) for i in range(len(y_pred_cnn))]

# get prediction metrics for each of the classifiers in isolation
y_pred_cnn = np.argmax(cnn_model.predict(X_cnn_test), axis=1)
y_pred_adaboost = adaboost_model.predict(X_adaboost_test)

# evaluate results
print("COMBINED RESULTS")
report = classification_report(y_test, y_pred, output_dict=True)
print(report)
print("Sensitivity ", report['1']['recall'])
print("Specificity ", report['0']['recall'])
print("Accuracy ", report['accuracy'])

print("ADABOOST RESULTS")
report = classification_report(y_test, y_pred_adaboost, output_dict=True)
print(report)
print("Sensitivity ", report['1']['recall'])
print("Specificity ", report['0']['recall'])
print("Accuracy ", report['accuracy'])

print("CNN RESULTS")
report = classification_report(y_test, y_pred_cnn, output_dict=True)
print(report)
print("Sensitivity ", report['1']['recall'])
print("Specificity ", report['0']['recall'])
print("Accuracy ", report['accuracy'])
# Out:
# /Users/austinatmaja/Documents/4B/SmartScope/classifier_env/lib/python3.6/site-packages/scipy/signal/spectral.py:1963: UserWarning: nperseg = 256 is greater than input length  = 150, using nperseg = 150
#   .format(nperseg, input_length))
# /Users/austinatmaja/Documents/4B/SmartScope/classifier_env/lib/python3.6/site-packages/scipy/signal/spectral.py:1963: UserWarning: nperseg = 256 is greater than input length  = 120, using nperseg = 120
#   .format(nperseg, input_length))
# /Users/austinatmaja/Documents/4B/SmartScope/classifier_env/lib/python3.6/site-packages/scipy/signal/spectral.py:1963: UserWarning: nperseg = 256 is greater than input length  = 210, using nperseg = 210
#   .format(nperseg, input_length))
# /Users/austinatmaja/Documents/4B/SmartScope/classifier_env/lib/python3.6/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=2048 is too small for input signal of length=150
#   n_fft, y.shape[-1]
# /Users/austinatmaja/Documents/4B/SmartScope/classifier_env/lib/python3.6/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=2048 is too small for input signal of length=120
#   n_fft, y.shape[-1]
# /Users/austinatmaja/Documents/4B/SmartScope/classifier_env/lib/python3.6/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=2048 is too small for input signal of length=210
#   n_fft, y.shape[-1]
# /Users/austinatmaja/Documents/4B/SmartScope/classifier_env/lib/python3.6/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=2048 is too small for input signal of length=510
#   n_fft, y.shape[-1]
# Processed a file set
# Processed a file set
# Processed a file set
# Processed a file set
# Processed a file set
# Processed a file set
# Epoch 1/200
# 73/73 [==============================] - 13s 164ms/step - loss: 1.5723 - accuracy: 0.5749 - val_loss: 0.9373 - val_accuracy: 0.3500
# Epoch 2/200
# 73/73 [==============================] - 17s 231ms/step - loss: 1.3484 - accuracy: 0.4503 - val_loss: 0.7718 - val_accuracy: 0.6923
# Epoch 3/200
# 73/73 [==============================] - 16s 225ms/step - loss: 1.2187 - accuracy: 0.5624 - val_loss: 0.7099 - val_accuracy: 0.8231
# Epoch 4/200
# 73/73 [==============================] - 14s 187ms/step - loss: 1.1458 - accuracy: 0.6717 - val_loss: 0.6239 - val_accuracy: 0.7577
# Epoch 5/200
# 73/73 [==============================] - 14s 187ms/step - loss: 1.0266 - accuracy: 0.7189 - val_loss: 0.6382 - val_accuracy: 0.7577
# Epoch 6/200
# 73/73 [==============================] - 15s 205ms/step - loss: 0.9631 - accuracy: 0.7787 - val_loss: 0.5078 - val_accuracy: 0.8154
# Epoch 7/200
# 73/73 [==============================] - 13s 182ms/step - loss: 0.9101 - accuracy: 0.7582 - val_loss: 0.5200 - val_accuracy: 0.7808
# Epoch 8/200
# 73/73 [==============================] - 14s 188ms/step - loss: 0.8624 - accuracy: 0.7760 - val_loss: 0.4625 - val_accuracy: 0.8269
# Epoch 9/200
# 73/73 [==============================] - 14s 190ms/step - loss: 0.8982 - accuracy: 0.7888 - val_loss: 0.5323 - val_accuracy: 0.8038
# Epoch 10/200
# 73/73 [==============================] - 15s 200ms/step - loss: 0.9237 - accuracy: 0.7413 - val_loss: 0.4812 - val_accuracy: 0.7808
# Epoch 11/200
# 73/73 [==============================] - 13s 185ms/step - loss: 0.7987 - accuracy: 0.7960 - val_loss: 0.5115 - val_accuracy: 0.7654
# Epoch 12/200
# 73/73 [==============================] - 14s 189ms/step - loss: 0.7943 - accuracy: 0.7904 - val_loss: 0.4981 - val_accuracy: 0.7346
# Epoch 13/200
# 73/73 [==============================] - 14s 186ms/step - loss: 0.7735 - accuracy: 0.7848 - val_loss: 0.4911 - val_accuracy: 0.7923
# Epoch 14/200
# 73/73 [==============================] - 14s 188ms/step - loss: 0.7812 - accuracy: 0.7818 - val_loss: 0.4163 - val_accuracy: 0.8192
# Epoch 15/200
# Epoch 35/200
# 73/73 [==============================] - 19s 256ms/step - loss: 0.6179 - accuracy: 0.8515 - val_loss: 0.4813 - val_accuracy: 0.8462
# Epoch 36/200
# 73/73 [==============================] - 18s 244ms/step - loss: 0.5937 - accuracy: 0.8616 - val_loss: 0.5618 - val_accuracy: 0.8000
# Epoch 37/200
# 73/73 [==============================] - 16s 220ms/step - loss: 0.5912 - accuracy: 0.8590 - val_loss: 0.5504 - val_accuracy: 0.7885
# Epoch 38/200
# 73/73 [==============================] - 17s 229ms/step - loss: 0.5695 - accuracy: 0.8669 - val_loss: 0.6177 - val_accuracy: 0.7808
# Epoch 39/200
# 73/73 [==============================] - 14s 193ms/step - loss: 0.6882 - accuracy: 0.8090 - val_loss: 0.5095 - val_accuracy: 0.8423
# Epoch 40/200
# 73/73 [==============================] - 15s 203ms/step - loss: 0.6291 - accuracy: 0.8419 - val_loss: 0.4985 - val_accuracy: 0.8615
# Epoch 41/200
# 73/73 [==============================] - 16s 213ms/step - loss: 0.6400 - accuracy: 0.8454 - val_loss: 0.6036 - val_accuracy: 0.8000
# Epoch 00041: early stopping
# COMBINED RESULTS
# {'0': {'precision': 0.9291845493562232, 'recall': 0.8608349900596421, 'f1-score': 0.8937048503611971, 'support': 503}, '1': {'precision': 0.6153846153846154, 'recall': 0.7724137931034483, 'f1-score': 0.6850152905198776, 'support': 145}, 'accuracy': 0.8410493827160493, 'macro avg': {'precision': 0.7722845823704193, 'recall': 0.8166243915815452, 'f1-score': 0.7893600704405374, 'support': 648}, 'weighted avg': {'precision': 0.8589669715385023, 'recall': 0.8410493827160493, 'f1-score': 0.8470073408288031, 'support': 648}}
# Sensitivity  0.7724137931034483
# Specificity  0.8608349900596421
# Accuracy  0.8410493827160493
# ADABOOST RESULTS
# {'0': {'precision': 0.8909774436090225, 'recall': 0.9423459244532804, 'f1-score': 0.9159420289855073, 'support': 503}, '1': {'precision': 0.75, 'recall': 0.6, 'f1-score': 0.6666666666666665, 'support': 145}, 'accuracy': 0.8657407407407407, 'macro avg': {'precision': 0.8204887218045113, 'recall': 0.7711729622266401, 'f1-score': 0.7913043478260868, 'support': 648}, 'weighted avg': {'precision': 0.8594315650236701, 'recall': 0.8657407407407407, 'f1-score': 0.8601628198246556, 'support': 648}}
# Sensitivity  0.6
# Specificity  0.9423459244532804
# Accuracy  0.8657407407407407
# CNN RESULTS
# {'0': {'precision': 0.9444444444444444, 'recall': 0.7773359840954275, 'f1-score': 0.8527808069792803, 'support': 503}, '1': {'precision': 0.5213675213675214, 'recall': 0.8413793103448276, 'f1-score': 0.6437994722955145, 'support': 145}, 'accuracy': 0.7916666666666666, 'macro avg': {'precision': 0.732905982905983, 'recall': 0.8093576472201276, 'f1-score': 0.7482901396373973, 'support': 648}, 'weighted avg': {'precision': 0.8497744539411206, 'recall': 0.7916666666666666, 'f1-score': 0.8060180083231908, 'support': 648}}
# Sensitivity  0.8413793103448276
# Specificity  0.7773359840954275
# Accuracy  0.7916666666666666
