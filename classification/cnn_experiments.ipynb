# %%
from classification.cnn_preprocess import CNNPreprocess
from classification.cnn import CNN
import numpy as np
import json

def get_train_data(file_sets, preprocessed_data_path=None):
    data = {}
    if preprocessed_data_path:
        with open(preprocessed_data_path) as json_file:
            data = json.load(json_file)
    else:
        cnn_preprocess = CNNPreprocess(file_sets=file_sets)
        data = cnn_preprocess.preprocess_data()
    
    return data

def evaluate_cnn(file_sets, preprocessed_data_path=None):
    
    data = get_train_data(file_sets, preprocessed_data_path)
    cnn_preprocess = CNNPreprocess(file_sets=file_sets)

    X = np.array(data["values"])
    y = np.array(data["labels"])

    cnn = CNN()
    report = cnn.validate_model_train_test(X, y)
    
    print(report)

challenge_data_folder = "/Users/austinatmaja/Documents/4B/SmartScope/murmur-classifier/challenge_data"
    
file_sets = [
    ([f"{challenge_data_folder}/training-a/a" + str(i).zfill(4) for i in range(1, 410)], f"{challenge_data_folder}/training-a/"),
    ([f"{challenge_data_folder}/training-b/b" + str(i).zfill(4) for i in range(1, 491)], f"{challenge_data_folder}/training-b/"),
    ([f"{challenge_data_folder}/training-c/c" + str(i).zfill(4) for i in range(1, 32)], f"{challenge_data_folder}/training-c/"),
    ([f"{challenge_data_folder}/training-d/d" + str(i).zfill(4) for i in range(1, 56)], f"{challenge_data_folder}/training-d/"),
    ([f"{challenge_data_folder}/training-e/e" + str(i).zfill(5) for i in range(1, 2142)], f"{challenge_data_folder}/training-e/"),
    ([f"{challenge_data_folder}/training-f/f" + str(i).zfill(4) for i in range(1, 115)], f"{challenge_data_folder}/training-f/"),
]

evaluate_cnn(file_sets)
# Out:
# Processed a file set
# Processed a file set
# Processed a file set
# Processed a file set
# Processed a file set
# Processed a file set
# Epoch 1/200
# 73/73 [==============================] - 15s 188ms/step - loss: 1.5495 - accuracy: 0.4344 - val_loss: 0.8852 - val_accuracy: 0.4231
# Epoch 2/200
# 73/73 [==============================] - 14s 191ms/step - loss: 1.2750 - accuracy: 0.4423 - val_loss: 0.7423 - val_accuracy: 0.6846
# Epoch 3/200
# 73/73 [==============================] - 18s 252ms/step - loss: 1.1554 - accuracy: 0.6353 - val_loss: 0.8310 - val_accuracy: 0.5423
# Epoch 4/200
# 73/73 [==============================] - 13s 183ms/step - loss: 1.0985 - accuracy: 0.6373 - val_loss: 0.7665 - val_accuracy: 0.6808
# Epoch 5/200
# 73/73 [==============================] - 16s 219ms/step - loss: 1.0903 - accuracy: 0.6687 - val_loss: 0.7812 - val_accuracy: 0.6577
# Epoch 6/200
# 73/73 [==============================] - 14s 189ms/step - loss: 0.9999 - accuracy: 0.7468 - val_loss: 0.8227 - val_accuracy: 0.6615
# Epoch 23/200
# 73/73 [==============================] - 13s 172ms/step - loss: 0.7174 - accuracy: 0.8394 - val_loss: 0.4824 - val_accuracy: 0.8154
# Epoch 24/200
# 73/73 [==============================] - 14s 191ms/step - loss: 0.7360 - accuracy: 0.8429 - val_loss: 0.5757 - val_accuracy: 0.7808
# Epoch 25/200
# 73/73 [==============================] - 13s 178ms/step - loss: 0.7490 - accuracy: 0.8180 - val_loss: 0.5544 - val_accuracy: 0.7923
# Epoch 26/200
# 73/73 [==============================] - 13s 171ms/step - loss: 0.7128 - accuracy: 0.8545 - val_loss: 0.6024 - val_accuracy: 0.7846
# Epoch 27/200
# 73/73 [==============================] - 13s 173ms/step - loss: 0.7509 - accuracy: 0.8285 - val_loss: 0.6045 - val_accuracy: 0.8115
# Epoch 28/200
# 73/73 [==============================] - 14s 192ms/step - loss: 0.7257 - accuracy: 0.8428 - val_loss: 0.5091 - val_accuracy: 0.8154
# Epoch 29/200
# 73/73 [==============================] - 13s 176ms/step - loss: 0.7135 - accuracy: 0.8631 - val_loss: 0.5335 - val_accuracy: 0.8038
# Epoch 30/200
# 73/73 [==============================] - 13s 176ms/step - loss: 0.7274 - accuracy: 0.8426 - val_loss: 0.5029 - val_accuracy: 0.8192
# Epoch 31/200
# 73/73 [==============================] - 13s 176ms/step - loss: 0.7050 - accuracy: 0.8457 - val_loss: 0.5451 - val_accuracy: 0.7962
# Epoch 32/200
# 73/73 [==============================] - 15s 204ms/step - loss: 0.6895 - accuracy: 0.8505 - val_loss: 0.6602 - val_accuracy: 0.7615
# Epoch 33/200
# 73/73 [==============================] - 13s 172ms/step - loss: 0.7714 - accuracy: 0.8275 - val_loss: 0.5929 - val_accuracy: 0.8000
# Epoch 34/200
# 73/73 [==============================] - 13s 174ms/step - loss: 0.7094 - accuracy: 0.8415 - val_loss: 0.5398 - val_accuracy: 0.8115
# Epoch 35/200
# 73/73 [==============================] - 13s 182ms/step - loss: 0.6874 - accuracy: 0.8495 - val_loss: 0.5741 - val_accuracy: 0.7885
# Epoch 36/200
# 73/73 [==============================] - 13s 181ms/step - loss: 0.6956 - accuracy: 0.8617 - val_loss: 0.6041 - val_accuracy: 0.7885
# Epoch 37/200
# 73/73 [==============================] - 13s 182ms/step - loss: 0.6630 - accuracy: 0.8483 - val_loss: 0.5676 - val_accuracy: 0.7962
# Epoch 00037: early stopping
#               precision    recall  f1-score   support
#
#            0       0.95      0.82      0.88       516
#            1       0.53      0.82      0.64       132
#
#     accuracy                           0.82       648
#    macro avg       0.74      0.82      0.76       648
# weighted avg       0.86      0.82      0.83       648
